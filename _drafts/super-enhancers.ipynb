# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import math
import matplotlib.pyplot as plt
import pandas as pd

# %%
h3k27ac = pd.read_csv("/home/mgymrek/Downloads/encode/wgEncodeBroadHistoneGm12878H3k27acStdPk.broadPeak", \
                       names=["chrom","start","end","name","score","strand","signal","p","q"], sep="\t")
h3k27me3 = pd.read_csv("/home/mgymrek/Downloads/encode/wgEncodeBroadHistoneGm12878H3k27me3StdPk.broadPeak", \
                       names=["chrom","start","end","name","score","strand","signal","p","q"], sep="\t")
h3k36me3 = pd.read_csv("/home/mgymrek/Downloads/encode/wgEncodeBroadHistoneGm12878H3k36me3StdPk.broadPeak", \
                       names=["chrom","start","end","name","score","strand","signal","p","q"], sep="\t")
h3k4me3 = pd.read_csv("/home/mgymrek/Downloads/encode/wgEncodeBroadHistoneGm12878H3k4me3StdPk.broadPeak", \
                       names=["chrom","start","end","name","score","strand","signal","p","q"], sep="\t")
ctcf = pd.read_csv("/home/mgymrek/Downloads/encode/wgEncodeBroadHistoneGm12878CtcfStdPk.broadPeak", \
                       names=["chrom","start","end","name","score","strand","signal","p","q"], sep="\t")

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(sorted(h3k27ac["signal"].values)[-1000:], lw=3, color="black")
ax.set_xlabel("Peak ranked by H3K27ac", size=20)
ax.set_ylabel("H3K27ac signal", size=20)
ax.set_xticklabels(map(int, ax.get_xticks()), size=15, )
ax.set_yticklabels(ax.get_yticks(), size=15);
ax.axvline(x=960, color="gray", linestyle="dashed", lw=2);

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(sorted(h3k27me3["signal"].values)[-1000:], lw=3, color="red")
ax.set_xlabel("Peak ranked by H3K27me3", size=20)
ax.set_ylabel("H3K27me3 signal", size=20)
ax.set_xticklabels(map(int, ax.get_xticks()), size=15, )
ax.set_yticklabels(ax.get_yticks(), size=15);
ax.axvline(x=970, color="gray", linestyle="dashed", lw=2);

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(sorted(h3k36me3["signal"].values)[-1000:], lw=3, color="green")
ax.set_xlabel("Peak ranked by H3K36me3", size=20)
ax.set_ylabel("H3K36me3 signal", size=20)
ax.set_xticklabels(map(int, ax.get_xticks()), size=15, )
ax.set_yticklabels(ax.get_yticks(), size=15);
ax.axvline(x=990, color="gray", linestyle="dashed", lw=2);

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(sorted(h3k4me3["signal"].values)[-1000:], lw=3, color="orange")
ax.set_xlabel("Peak ranked by H3K4me3", size=20)
ax.set_ylabel("H3K4me3 signal", size=20)
ax.set_xticklabels(map(int, ax.get_xticks()), size=15, )
ax.set_yticklabels(ax.get_yticks(), size=15);
ax.axvline(x=965, color="gray", linestyle="dashed", lw=2);

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(sorted(ctcf["signal"].values)[-1000:], lw=3, color="blue")
ax.set_xlabel("Peak ranked by CTCF", size=20)
ax.set_ylabel("CTCF signal", size=20)
ax.set_xticklabels(map(int, ax.get_xticks()), size=15, )
ax.set_yticklabels(ax.get_yticks(), size=15);
